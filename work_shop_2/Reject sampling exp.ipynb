# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
#this function is the numerator of the target distribution
def t(x):
    if x >= 0:
        return  np.exp(-(x/5)**4)
    else: 
        return  np.exp(-(1/10*x)**2+x)

# %%
#normal PDF
def g(x, mu, sigma):
    return 1/np.sqrt(2*np.pi)/sigma * np.exp(-0.5*((x-mu)/sigma)**2)

# %%
NORM_CONST = 5.51

# %%
x_vals = np.arange(-10,10,.1)
t_vals = [t(x) for x in x_vals]
f_vals = [t/NORM_CONST for t in t_vals]
plt.figure(figsize=(12,6))
plt.plot(x_vals, t_vals)
plt.plot(x_vals, f_vals)
plt.legend(['t(x)', 'f(x)'], fontsize = 18)
plt.xlabel('x', fontsize = 18)
plt.ylabel('Density', fontsize = 18)
plt.axvline(0, color='b', linestyle='--')

# %%
product = [x_vals[i]*f_vals[i] for i in range(len(x_vals))]

# %%
TRUE_EXP = np.trapz(y=product, x=x_vals)
# Out:
# C:\Users\Ilia\AppData\Local\Temp\ipykernel_2684\3315585308.py:1: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   TRUE_EXP = np.trapz(y=product,x=x_vals)

# %%
x_vals = np.arange(-10,10,.1)
t_vals = [t(x) for x in x_vals]
g_vals = g(x_vals, 0, 0.8)
M = 1

plt.figure(figsize=(10,4))
plt.plot(x_vals, t_vals)
plt.plot(x_vals, M*g_vals)
plt.xlabel('x', fontsize=20)
plt.ylabel('Density', fontsize=20)
plt.legend(['t(x)', 'S*h(x)'], fontsize=20)

plt.title("M=%s"%M, fontsize=20)
# Out:
# Text(0.5, 1.0, 'M=1')

# %%
M = 3

plt.figure(figsize=(10,4))
plt.plot(x_vals, t_vals)
plt.plot(x_vals, M*g_vals)
plt.xlabel('x', fontsize=20)
plt.ylabel('Density', fontsize=20)
plt.legend(['t(x)', 'S*h(x)'], fontsize=20)

plt.title("M=%s"%M, fontsize=20)
# Out:
# Text(0.5, 1.0, 'M=3')

# %%
M = 100

plt.figure(figsize=(10,4))
plt.plot(x_vals, t_vals)
plt.plot(x_vals, M*g_vals)
plt.xlabel('x', fontsize=20)
plt.ylabel('Density', fontsize=20)
plt.legend(['t(x)', 'S*h(x)'], fontsize=20)

plt.title("M=%s"%M, fontsize=20)
# Out:
# Text(0.5, 1.0, 'M=100')

# %%
#collect all accepted samples here
samples = []

#try this many candidates
N = 100000

for _ in range(N):
    #sample a candidate
    candidate = np.random.normal(0, 0.8)
    
    #calculate probability of accepting this candidate
    prob_accept = t(candidate) / (M*g(candidate, 0, 0.8))
    
    #accept with the calculated probability
    if np.random.random() < prob_accept:
        samples.append(candidate)

# %%
print("Num Samples Collected: %s"%len(samples))
# Out:
# Num Samples Collected: 3459

# %%
print("Efficiency: %s"%round(len(samples) / N, 3))
# Out:
# Efficiency: 0.035

# %%
plt.figure(figsize=(10,4))
plt.hist(samples, bins=200, density=True)
plt.xlabel('x', fontsize=20)
plt.xlabel('Density', fontsize=20)
plt.plot(x_vals, [t/NORM_CONST for t in t_vals], linewidth=2)
plt.xlim(-15,15)

plt.title('Empirical Exp. Value: %s\nTrue Exp. Value: %s'%(round(np.mean(samples), 2), round(np.mean(TRUE_EXP), 2)), fontsize=20)
# Out:
# Text(0.5, 1.0, 'Empirical Exp. Value: 0.65\nTrue Exp. Value: 1.84')

# %%
x_vals = np.arange(-30,30,.1)
t_vals = [t(x) for x in x_vals]
g_vals = g(x_vals, 0, 5)
M = 1

plt.figure(figsize=(10,4))
plt.plot(x_vals, t_vals)
plt.plot(x_vals, M*g_vals)
plt.xlabel('x', fontsize=20)
plt.ylabel('Density', fontsize=20)
plt.legend(['t(x)', 'S*h(x)'], fontsize=20)

plt.title("M=%s"%M, fontsize=20)
# Out:
# Text(0.5, 1.0, 'M=1')

# %%
M = 15

plt.figure(figsize=(10,4))
plt.plot(x_vals, t_vals)
plt.plot(x_vals, M*g_vals)
plt.xlabel('x', fontsize=20)
plt.ylabel('Density', fontsize=20)
plt.legend(['t(x)', 'S*h(x)'], fontsize=20)

plt.title("M=%s"%M, fontsize=20)
# Out:
# Text(0.5, 1.0, 'M=15')

# %%
M = 15

plt.figure(figsize=(10,4))
plt.plot(x_vals, t_vals)
plt.plot(x_vals, M*g_vals)
plt.xlabel('x', fontsize=20)
plt.ylabel('Density', fontsize=20)
plt.legend(['t(x)', 'S*h(x)'], fontsize=20)

plt.title("M=%s"%M, fontsize=20)
plt.ylim(0, 0.0001)
# Out:
# (0.0, 0.0001)

# %%
samples = []
N = 100000
for _ in range(N):
    #get a candidate from uniform distribution
    candidate = np.random.normal(0, 5)
    
    #calculate probabailty of accepting this sample
    prob_accept = t(candidate) / (M*g(candidate, 0, 5))
    
    #accept sample with this probability
    if np.random.random() < prob_accept:
        samples.append(candidate)

# %%
print("Num Samples Collected: %s"%len(samples))
# Out:
# Num Samples Collected: 36673

# %%
print("Efficiency: %s"%round(len(samples) / N, 3))
# Out:
# Efficiency: 0.367

# %%
plt.figure(figsize=(10,4))
plt.hist(samples, bins=200, density=True)
plt.xlabel('x', fontsize=20)
plt.xlabel('Density', fontsize=20)
plt.plot(x_vals, [t/NORM_CONST for t in t_vals], linewidth=3)
plt.xlim(-15,15)

plt.title('Empirical Exp. Value: %s\nTrue Exp. Value: %s'%(round(np.mean(samples), 2), round(np.mean(TRUE_EXP), 2)), fontsize=20)
# Out:
# Text(0.5, 1.0, 'Empirical Exp. Value: 1.82\nTrue Exp. Value: 1.84')

# %%
plt.figure(figsize=(10,4))
plt.hist(samples, bins=200, density=True)
plt.xlabel('x', fontsize=20)
plt.xlabel('Density', fontsize=20)
#plt.plot(x_vals, [f/NORM_CONST for f in t_vals], linewidth=3)
plt.xlim(-15,15)

plt.title('Empirical Exp. Value: %s\nTrue Exp. Value: %s'%(round(np.mean(samples), 2), round(np.mean(TRUE_EXP), 2)), fontsize=20)
# Out:
# Text(0.5, 1.0, 'Empirical Exp. Value: 1.82\nTrue Exp. Value: 1.84')
